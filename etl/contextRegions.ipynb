# %%
import numpy as np
import pandas as pd

# %%
acc23 = pd.read_excel('C:\\my\\prog\\pet banks\\raw_data\\regions\\1\\tekprivl202312rus.xlsx', sheet_name=0)

# %%
def clean_month(df):
    df = df.copy()
    df = df.iloc[7:27, [2,5]].apply(pd.to_numeric, errors='raise').reset_index(drop=True)
    df.columns = ['juridical', 'natural']
    return df

# %% [markdown]
# Добавить данные из депозитов (привлеченные банками!!!!) смещенные назад на месяц чтобы не было простой корреляции
