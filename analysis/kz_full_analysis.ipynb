# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql+psycopg2://postgres:qwerty123@localhost:5432/credits_total_kz")
df = pd.read_sql("select * from macro_kz", engine)

# %%
df.head()
# Out:
#        month  Депозиты небанковских юридически  Депозиты физических лиц  \
# 0 2022-01-01                               7.9                      8.4
# 1 2022-02-01                              10.3                      8.5
# 2 2022-03-01                              10.9                      9.9
# 3 2022-04-01                              11.6                     10.6
# 4 2022-05-01                              11.5                     11.0
#
#    до 1 месяца  до востребования  от 1 года до 5 лет  от 1 до 3 месяцев  \
# 0         7.95              0.10                8.40               8.80
# 1        10.50              0.05                8.65               8.80
# 2        11.10              0.10               10.05              10.40
# 3        11.75              0.35               10.50              10.55
# 4        11.70              1.75               10.75              11.05
#
#    от 3 месяцев до 1 года  свыше 5 лет  срочные, всего  условные  target_x  \
# ...

# %% [markdown]
# Распределение юр и физ лиц

# %%
pie_values = [df.iloc[:, 1].sum(), df.iloc[:,2].sum()]
plt.figure(figsize=(4, 4))
plt.pie(pie_values, labels=df.columns[1:3],  autopct="%1.1f%%")
plt.axis("equal")
plt.show()

# %% [markdown]
# Изменение общего кол-ва кредитов в зависимости от месяца

# %%
plt.plot(df['month'], df['target_y'])
plt.xticks(rotation=45)
plt.show()
